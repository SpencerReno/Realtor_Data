# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Import

# %%
data = pd.read_csv('./data_files/realtor-dataset-100k.csv')
data.head()
# Out:
#      status   price  bed  bath  acre_lot  \
# 0  for_sale  105000  3.0   2.0      0.12
# 1  for_sale   80000  4.0   2.0      0.08
# 2  for_sale   67000  2.0   1.0      0.15
# 3  for_sale  145000  4.0   2.0      0.10
# 4  for_sale   65000  6.0   2.0      0.05
#
#                                         full_address  \
# 0  Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1            Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2            556G 556-G 16 St, Juana Diaz, PR, 00795
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                    14 Navarro, Mayaguez, PR, 00680
#
#                                           street        city        state  \
# 0                   Sector Yahuecas Titulo # V84    Adjuntas  Puerto Rico
# 1                             Km 78 9 Carr # 135    Adjuntas  Puerto Rico
# 2                               556G 556-G 16 St  Juana Diaz  Puerto Rico
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce       Ponce  Puerto Rico
# 4                                     14 Navarro    Mayaguez  Puerto Rico
#
#    zip_code  house_size sold_date
# 0     601.0       920.0       NaN
# 1     601.0      1527.0       NaN
# 2     795.0       748.0       NaN
# 3     731.0      1800.0       NaN
# 4     680.0         NaN       NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   status        100000 non-null  object
#  1   price         100000 non-null  int64
#  2   bed           75050 non-null   float64
#  3   bath          75112 non-null   float64
#  4   acre_lot      85987 non-null   float64
#  5   full_address  100000 non-null  object
#  6   street        99916 non-null   object
#  7   city          99948 non-null   object
#  8   state         100000 non-null  object
#  9   zip_code      99805 non-null   float64
#  10  house_size    75082 non-null   float64
#  11  sold_date     28745 non-null   object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 9.2+ MB

# %% [markdown]
# ### Data Cleaning

# %%
data.isnull().sum()
# Out:
# status              0
# price               0
# bed             24950
# bath            24888
# acre_lot        14013
# full_address        0
# street             84
# city               52
# state               0
# zip_code          195
# house_size      24918
# sold_date       71255
# dtype: int64

# %% [markdown]
# Replacing Null Values in the sold_date column if there is no date most likely means the house hasn't been sold

# %%
data['sold_date'].replace(np.nan, 'Not Sold', inplace=True)
data.head()
# Out:
#      status   price  bed  bath  acre_lot  \
# 0  for_sale  105000  3.0   2.0      0.12
# 1  for_sale   80000  4.0   2.0      0.08
# 2  for_sale   67000  2.0   1.0      0.15
# 3  for_sale  145000  4.0   2.0      0.10
# 4  for_sale   65000  6.0   2.0      0.05
#
#                                         full_address  \
# 0  Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1            Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2            556G 556-G 16 St, Juana Diaz, PR, 00795
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                    14 Navarro, Mayaguez, PR, 00680
#
#                                           street        city        state  \
# 0                   Sector Yahuecas Titulo # V84    Adjuntas  Puerto Rico
# 1                             Km 78 9 Carr # 135    Adjuntas  Puerto Rico
# 2                               556G 556-G 16 St  Juana Diaz  Puerto Rico
# 3  R5 Comunidad El Paraso Calle De Oro R-5 Ponce       Ponce  Puerto Rico
# 4                                     14 Navarro    Mayaguez  Puerto Rico
#
#    zip_code  house_size sold_date
# 0     601.0       920.0  Not Sold
# 1     601.0      1527.0  Not Sold
# 2     795.0       748.0  Not Sold
# 3     731.0      1800.0  Not Sold
# 4     680.0         NaN  Not Sold

# %% [markdown]
# I think the best way to replace the other Null vaules is to use the average values based on that cities location. However, with the missing values in the cities column we have to address those first

# %%
data['city'].value_counts().count()
# Out:
# 525

# %% [markdown]
# since City, Street, and Zip_code are all values unique to a specific house these cant be estimated. Best option for these is to replace with a filler such as "Missing".

# %%
data['city'].fillna('Missing', inplace=True)
data['street'].fillna('Missing', inplace=True)
data['zip_code'].fillna('Missing', inplace=True)

# %% [markdown]
# How that all the unique identifiers have been replaced and now we are left with just house attributes these can be replaced with estimated numbers. To combat this for beds, baths, and acre_lot im going to use the mode number (Most Occurring) based on the city location. Most houses within a city are bulit the same or to a standard around the area.

# %%
data.isnull().sum()
# Out:
# status              0
# price               0
# bed             24950
# bath            24888
# acre_lot        14013
# full_address        0
# street              0
# city                0
# state               0
# zip_code            0
# house_size      24918
# sold_date           0
# dtype: int64

# %%
city_bed_mode = data.groupby('city')['bed'].agg(pd.Series.mode).to_dict()

# %%
data['bed'].fillna(data['city'],inplace=True)

# %% [markdown]
# Replacing incosistant values with the overall average of 3 beds

# %%
for key, value in city_bed_mode.items():
    if not isinstance(value, float):
        city_bed_mode[key] = 3

# %% [markdown]
# Replacing the Placeholder city names with the correct most common bed value

# %%
data['bed'].replace(city_bed_mode, inplace=True)

# %% [markdown]
# Now Repeated Process for Bath, Acre, and House Size

# %%
city_bath_mode = data.groupby('city')['bath'].agg(pd.Series.mode).to_dict()
city_acre_mode = data.groupby('city')['acre_lot'].agg(pd.Series.mode).to_dict()
city_house_mode = data.groupby('city')['house_size'].agg(pd.Series.mode).to_dict()

# %%
data['bath'].fillna(data['city'],inplace=True)
data['acre_lot'].fillna(data['city'],inplace=True)
data['house_size'].fillna(data['city'],inplace=True)

# %%
## Bath Fix (most common overall is 2 baths)
for key, value in city_bath_mode.items():
    if not isinstance(value, float):
        city_bath_mode[key] = 2

## Acre Fix (most common overall is 0.09 baths)
for key, value in city_acre_mode.items():
    if not isinstance(value, float):
        city_acre_mode[key] = 0.09

## Acre Fix (most common overall is 0.09 baths)
for key, value in city_house_mode.items():
    if not isinstance(value, float):
        city_house_mode[key] = 1200

# %%
data['bath'].replace(city_bath_mode, inplace=True)
data['acre_lot'].replace(city_acre_mode, inplace=True)
data['house_size'].replace(city_house_mode, inplace=True)

# %%
data.isna().sum()
# Out:
# status          0
# price           0
# bed             0
# bath            0
# acre_lot        0
# full_address    0
# street          0
# city            0
# state           0
# zip_code        0
# house_size      0
# sold_date       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 85141

# %% [markdown]
# Since there are duplicated houses for some reason with in the data I will only keep the 1st iteration of the house

# %%
data[data.duplicated(subset='full_address', keep=False)].sort_values('full_address')[:10]
# Out:
#          status  price  bed  bath  acre_lot                      full_address  \
# 49070  for_sale  75000  3.0   2.0      0.29  0 Ashmun, Springfield, MA, 01101
# 68374  for_sale  75000  3.0   2.0      0.29  0 Ashmun, Springfield, MA, 01101
# 36314  for_sale  75000  3.0   2.0      0.29  0 Ashmun, Springfield, MA, 01101
# 51831  for_sale  75000  3.0   2.0      0.29  0 Ashmun, Springfield, MA, 01101
# 50721  for_sale  75000  3.0   2.0      0.29  0 Ashmun, Springfield, MA, 01101
# 44000  for_sale  75000  3.0   2.0      0.29  0 Ashmun, Springfield, MA, 01101
# 35809  for_sale  75000  3.0   2.0      0.29  0 Ashmun, Springfield, MA, 01101
# 38260  for_sale  75000  3.0   2.0      0.29  0 Ashmun, Springfield, MA, 01101
# 41190  for_sale  75000  3.0   2.0      0.29  0 Ashmun, Springfield, MA, 01101
# 29139  for_sale  75000  3.0   2.0      0.29  0 Ashmun, Springfield, MA, 01101
#
#          street         city          state zip_code  house_size sold_date
# 49070  0 Ashmun  Springfield  Massachusetts     1101       580.0  Not Sold
# 68374  0 Ashmun  Springfield  Massachusetts     1101       580.0  Not Sold
# 36314  0 Ashmun  Springfield  Massachusetts     1101       580.0  Not Sold
# 51831  0 Ashmun  Springfield  Massachusetts     1101       580.0  Not Sold
# 50721  0 Ashmun  Springfield  Massachusetts     1101       580.0  Not Sold
# 44000  0 Ashmun  Springfield  Massachusetts     1101       580.0  Not Sold
# 35809  0 Ashmun  Springfield  Massachusetts     1101       580.0  Not Sold
# 38260  0 Ashmun  Springfield  Massachusetts     1101       580.0  Not Sold
# 41190  0 Ashmun  Springfield  Massachusetts     1101       580.0  Not Sold
# 29139  0 Ashmun  Springfield  Massachusetts     1101       580.0  Not Sold

# %%
data.drop_duplicates(subset='full_address',keep='first', inplace=True)

# %% [markdown]
# Reseting index for inconsistancies after dropping duplicates

# %%
data.reset_index(inplace=True)
data.drop(columns=['index'], inplace=True)

# %%
data['status'].value_counts()
# Out:
# for_sale          14715
# ready_to_build        4
# Name: status, dtype: int64

# %% [markdown]
# If a there is a sold date listed the status needs to be changed from "For_sale" to SOLD

# %%
type(data.iloc[14718]['sold_date'])
# Out:
# str

# %% [markdown]
# Shows all rows with a date attached to the sold_date column

# %%
data[data.sold_date.str.contains(pat='[1-12]')]
# Out:
#          status   price  bed  bath  acre_lot  \
# 403    for_sale   76900  3.0   2.0      0.08
# 494    for_sale  110000  7.0   3.0      0.09
# 1009   for_sale  159000  3.0   2.0      0.09
# 1144   for_sale  380000  3.0   2.0     78.66
# 2245   for_sale  950000  5.0   4.0      0.99
# ...         ...     ...  ...   ...       ...
# 14711  for_sale  649900  4.0   3.0      0.37
# 14712  for_sale  379900  3.0   2.0      0.18
# 14714  for_sale  735000  3.0   2.0      0.90
# 14715  for_sale  785000  4.0   3.0      0.24
# 14718  for_sale  399900  3.0   1.0      0.09
#
#                                             full_address  \
# 403    E 331 Apt E 331 Alborada Unit E331, Canovanas,...
# 494                   B-2 Monte Elena, Dorado, PR, 00949
# 1009          784 Carretera Unit B302, Caguas, PR, 00725
# 1144   Km 12 5 Carretera 182 Km 12 5 Bo Guayabota Yab...
# 2245              46 Water Isle, Saint Thomas, VI, 00802
# ...                                                  ...
# 14711                    7 Reagan Rd, Milford, MA, 01757
# 14712            159 Garden City Dr, Cranston, RI, 02920
# 14714                   17 Sunset Rd, Bristol, RI, 02809
# 14715                 7 Agawam Rd, Barrington, RI, 02806
# 14718                106 Cedar St, Framingham, MA, 01702
#
#                                                   street          city  \
# 403                   E 331 Apt E 331 Alborada Unit E331     Canovanas
# 494                                      B-2 Monte Elena        Dorado
# 1009                             784 Carretera Unit B302        Caguas
# 1144   Km 12 5 Carretera 182 Km 12 5 Bo Guayabota Yab...       Yabucoa
# 2245                                       46 Water Isle  Saint Thomas
# ...                                                  ...           ...
# 14711                                        7 Reagan Rd       Milford
# 14712                                 159 Garden City Dr      Cranston
# 14714                                       17 Sunset Rd       Bristol
# 14715                                        7 Agawam Rd    Barrington
# 14718                                       106 Cedar St    Framingham
#
#                 state zip_code  house_size   sold_date
# 403       Puerto Rico      729      1200.0   2/28/2020
# 494       Puerto Rico      949      1192.0   6/28/2019
# 1009      Puerto Rico      725      1625.0   9/15/2021
# 1144      Puerto Rico      767      1200.0   3/15/2021
# 2245   Virgin Islands      802      5000.0  10/11/2013
# ...               ...      ...         ...         ...
# 14711   Massachusetts     1757      2255.0   6/28/1994
# 14712    Rhode Island     2920      1497.0    7/7/2017
# 14714    Rhode Island     2809      1727.0   6/29/1999
# 14715    Rhode Island     2806      2166.0   9/23/2021
# 14718   Massachusetts     1702      1402.0    8/1/1989
#
# [5295 rows x 12 columns]

# %% [markdown]
# Updates all sold houses status to sold

# %%
for i, row in data.iterrows():
    if row['sold_date'] != 'Not Sold':
        data.loc[i, 'status'] = 'SOLD'

# %% [markdown]
# More even distribution between for_sale and sold still not great but a lot better

# %%
data['status'].value_counts()
# Out:
# for_sale          9420
# SOLD              5295
# ready_to_build       4
# Name: status, dtype: int64

# %% [markdown]
# The full address is redundent since we already have city, state, zip_code, and street

# %%
data.drop(columns=['full_address'], inplace=True)

# %%
data
# Out:
#          status   price  bed  bath  acre_lot  \
# 0      for_sale  105000  3.0   2.0      0.12
# 1      for_sale   80000  4.0   2.0      0.08
# 2      for_sale   67000  2.0   1.0      0.15
# 3      for_sale  145000  4.0   2.0      0.10
# 4      for_sale   65000  6.0   2.0      0.05
# ...         ...     ...  ...   ...       ...
# 14714      SOLD  735000  3.0   2.0      0.90
# 14715      SOLD  785000  4.0   3.0      0.24
# 14716  for_sale  639900  2.0   2.0      0.09
# 14717  for_sale  465000  3.0   2.0      0.36
# 14718      SOLD  399900  3.0   1.0      0.09
#
#                                               street        city  \
# 0                       Sector Yahuecas Titulo # V84    Adjuntas
# 1                                 Km 78 9 Carr # 135    Adjuntas
# 2                                   556G 556-G 16 St  Juana Diaz
# 3      R5 Comunidad El Paraso Calle De Oro R-5 Ponce       Ponce
# 4                                         14 Navarro    Mayaguez
# ...                                              ...         ...
# 14714                                   17 Sunset Rd     Bristol
# 14715                                    7 Agawam Rd  Barrington
# 14716                          15 Morgan Dr Unit 109      Natick
# 14717                                    16 Park Ave  Framingham
# 14718                                   106 Cedar St  Framingham
#
#                state zip_code  house_size  sold_date
# 0        Puerto Rico      601       920.0   Not Sold
# 1        Puerto Rico      601      1527.0   Not Sold
# 2        Puerto Rico      795       748.0   Not Sold
# 3        Puerto Rico      731      1800.0   Not Sold
# 4        Puerto Rico      680      1000.0   Not Sold
# ...              ...      ...         ...        ...
# 14714   Rhode Island     2809      1727.0  6/29/1999
# 14715   Rhode Island     2806      2166.0  9/23/2021
# 14716  Massachusetts     1760      1705.0   Not Sold
# 14717  Massachusetts     1701      1442.0   Not Sold
# 14718  Massachusetts     1702      1402.0   8/1/1989
#
# [14719 rows x 11 columns]

# %%
data.to_csv(path_or_buf='D:\Data_Science_Documents\Realtor_Data\data_files\clean_data.csv')
